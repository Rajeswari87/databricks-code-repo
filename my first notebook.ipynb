# %% [markdown]
# ##Magic Commands
# **My Name:** <span style="color:green">Rajeswari</span>
# ![Team Photo](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql
CREATE VOLUME IF NOT EXISTS usage_metrics;

# %%
# %py
import requests

url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
data = requests.get(url).text
print(data)
dbutils.fs.put(
    "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",
    data, overwrite=True
)
dbutils.fs.ls("/Volumes/workspace/default/usage_metrics/")

# %%
# %run ./4_child_notebook

# %%
# %fs head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
df1 = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", header=True, inferSchema=True)
display(df1)

# %%
# %py
df1.write.saveAsTable("default.mobile_os_usage")

# %%
spark.read.table("default.mobile_os_usage").show()

# %%
def to_upper_case(a):
    return a.upper()
print(to_upper_case("hello"))

# %%
# %pip install pandas

# %%
import pandas as pd

df = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df)

# %%
# %sh
echo "Magic commands tasks completed"
